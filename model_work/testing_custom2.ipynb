# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo_model/runs/detect/train-5/weights/best.pt")

# %%
import glob

# %%
frames = glob.glob("frames_testing/*.jpg")

# %%
results = model(frames, stream=True)

# %%
for result in results:
    print(result)
# Out:
# 0: 480x640 15 persons, 91.5ms
# 1: 480x640 11 persons, 91.5ms
# 2: 480x640 2 persons, 91.5ms
# 3: 480x640 9 persons, 91.5ms
# 4: 480x640 8 persons, 91.5ms
# 5: 480x640 10 persons, 91.5ms
# 6: 480x640 6 persons, 91.5ms
# 7: 480x640 10 persons, 91.5ms
# 8: 480x640 8 persons, 91.5ms
# 9: 480x640 7 persons, 91.5ms
# 10: 480x640 6 persons, 91.5ms
# 11: 480x640 7 persons, 91.5ms
# 12: 480x640 10 persons, 91.5ms
# 13: 480x640 13 persons, 91.5ms
# 14: 480x640 6 persons, 91.5ms
# 15: 480x640 6 persons, 91.5ms
# 16: 480x640 8 persons, 91.5ms
# 17: 480x640 18 persons, 91.5ms
# 18: 480x640 14 persons, 91.5ms
# 19: 480x640 16 persons, 91.5ms
# 20: 480x640 11 persons, 91.5ms
# 21: 480x640 10 persons, 91.5ms
# 22: 480x640 9 persons, 91.5ms
# 23: 480x640 6 persons, 91.5ms
# 24: 480x640 9 persons, 91.5ms
# 25: 480x640 8 persons, 91.5ms
# 26: 480x640 9 persons, 91.5ms
# 27: 480x640 8 persons, 91.5ms
# 28: 480x640 8 persons, 91.5ms
# 29: 480x640 13 persons, 91.5ms
# 30: 480x640 9 persons, 91.5ms
# ...
