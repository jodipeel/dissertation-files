# %% [markdown]
# Transfer learning to train the two custom models. Model is trained on custom-made dataset. Epocchs values were changed when training different models.

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\jodip\yolo_model

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo26n.yaml")

# %%
results = model.train(data="person.yaml", epochs=100, rect=True)
# Out:
# New https://pypi.org/project/ultralytics/8.4.51 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.48  Python-3.11.5 torch-2.11.0+cpu CPU (11th Gen Intel Core i5-1155G7 @ 2.50GHz)
# ...
