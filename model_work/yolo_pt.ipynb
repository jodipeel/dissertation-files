# %% [markdown]
# Import relevant libraries.

# %%
from ultralytics import YOLO
import glob
import os

# %% [markdown]
# Initialise pretrained model.

# %%
model = YOLO("yolo26n.pt")

# %%
os.chdir("frames_thresh_small")

# %%
frames = glob.glob("*.jpg")

# %% [markdown]
# Test all images.

# %%
results = model(frames, stream=True)

# %%
for result in results:
    print(result)

# %% [markdown]
# Results were copied and pasted and processed in a separate file, due to the nature of the returned data.
